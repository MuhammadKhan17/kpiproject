# %%
import pandas as pd

# Load datasets
data_ctr = pd.read_csv('clickThroughRate.csv', skiprows=1, usecols=range(1, 49))
data_cvrBF = pd.read_csv('crvBF.csv', skiprows=1, usecols=range(1, 49))
data_cvrSV = pd.read_csv('crvSV.csv', skiprows=1, usecols=range(1, 49))
data_imps = pd.read_csv('impressions.csv', skiprows=1, usecols=range(1, 49))
data_internet = pd.read_csv('internetCVR.csv', skiprows=1, usecols=range(1, 49))
data_spend = pd.read_csv('spending.csv', skiprows=1, usecols=range(1, 49))

labeled_data = pd.read_csv('clean_data_Wes.csv', usecols=range(1, 34))
#dummy_data = pd.read_pickle('cleaned_dummies.pkl')  # doesn't work on here for some reason
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-1-c20dc7d63804> in <module>()
#       2
#       3 # Load datasets
# ----> 4 data_ctr = pd.read_csv('clickThroughRate.csv', skiprows=1, usecols=range(1, 49))
#       5 data_cvrBF = pd.read_csv('crvBF.csv', skiprows=1, usecols=range(1, 49))
#       6 data_cvrSV = pd.read_csv('crvSV.csv', skiprows=1, usecols=range(1, 49))
#
# /usr/local/lib/python3.7/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...

# %%
# Define data cleaning functions


def rename_cols(df, s):
  return [s + str(num) for num in range(df.shape[1])]


def p2f(x):
  # Change percentage to float
  if type(x) == str:
      return float(x.strip('%'))
  return x


def dollar2f(x):
  # Change dollar string to float
  if type(x) == str:
      x = x.replace(',', '')
      return float(x.strip('$'))
  return x


def clean_percentage_df(df, s):
  df.columns = rename_cols(df, s)
  df = df.applymap(p2f)
  return df


def clean_nonpercentage_df(df, s):
  df.columns = rename_cols(df, s)
  df = df.applymap(dollar2f)
  return df


# Cleaning data
data_ctr = clean_percentage_df(data_ctr, 'CTR_W')
data_cvrBF = clean_percentage_df(data_cvrBF, 'CVR(BF)_W')
data_cvrSV = clean_percentage_df(data_cvrSV, 'CVR(SV)_W')
data_internet = clean_percentage_df(data_internet, 'Internet_CVR(S)_W')
data_imps = clean_nonpercentage_df(data_imps, 'Impressions_W')
data_spend = clean_nonpercentage_df(data_spend, 'Spend_W')

# %%
# Combine weekly variables
week_data_combined = pd.concat([data_ctr, data_cvrBF, data_cvrSV, data_internet, data_imps, data_spend], axis=1)
week_data_combined.fillna(0, inplace=True)

# Grab features created to merge with dummy_data
feat_created = labeled_data.iloc[:, 18:]

# Remove raw date variables
# dummy_data = dummy_data.iloc[:, :122]

# Combine everything
cleaned_labeled_data = pd.concat([labeled_data, week_data_combined], axis=1)
# cleaned_dummy_data = pd.concat([dummy_data, feat_created, week_data_combined], axis=1)

# %%
cleaned_labeled_data.to_csv('labaled_data.csv', index=False)
# cleaned_dummy_data.to_csv('dummy_data.csv', index=False)
